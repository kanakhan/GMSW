# %% [markdown]
# <a href="https://colab.research.google.com/github/kanakhan/GMSW/blob/main/%ED%94%BC%EB%B2%97%ED%85%8C%EC%9D%B4%EB%B8%94_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 피벗(pivot talbe)

# %% [markdown]
# * 피벗테이블(pivot table): 데이터 칼럼 중에서 두 개 이상의 칼럼을 각각 행 인덱스와 열 인덱스로 사용하여 거기에 해당되는 데이터를 불러와 펼쳐놓거나 데이터의 집계 값을 구하는 표

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 행 1개 * 열1개 피벗테이블
# * (질문) 객실 등급('cplass')에 따라 아이, 남자성인, 여자성인('who)의 생존률은 어떠한 관계가 있는가?

# %% [markdown]
# *   행 2개 * 열1개 피벗테이블
# *   (질문)성별('sex')과 동행여부('alone'), 그리고 객실 등급('cplass')에 따른 생존자 수와 생존률을 어떻게 되는가?(전체 계산 값은 '전체'라고 라벨링)

# %% [markdown]
# * 행 2개 * 열 2개 피벗테이블
# * (질문) 성별('sex')과 동행여부('alone'), 그리고 객실 등급('cplass')과 데크('deck') 위치에 따라 따른 생존률을 어떻게 되는가?(전체 계산 값은 '전체'라고 라벨링)
