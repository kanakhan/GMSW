# %% [markdown]
# <a href="https://colab.research.google.com/github/kanakhan/GMSW/blob/main/pandas_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## pandas 입출력

# %% [markdown]
# * 판다스 파일별 입력함수

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 코랩(colab)에서 직접 csv파일 생성

# %%
# %%writefile example.csv
# a,b,c,d,e, program
# 1,2,3,4,5, pandas
# 6,7,8,9,10, numpy
# 11,12,13,14,15, python
# Out:
# Writing example.csv

# %%
# !ls

# !cat example.csv
# Out:
# example.csv  sample_data
# a,b,c,d,e, program
# 1,2,3,4,5, pandas
# 6,7,8,9,10, numpy
# 11,12,13,14,15, python

# %% [markdown]
# * 코랩(colab)에 로컬 컴퓨터 파일 업로드

# %% [markdown]
# * CSV파일 불어와 읽기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("example.csv")

df
# Out:
#     a   b   c   d   e  program
# 0   1   2   3   4   5   pandas
# 1   6   7   8   9  10    numpy
# 2  11  12  13  14  15   python

# %%
pd.read_csv("example.csv", names=[1,2,3,4,5])
# Out:
#      1   2   3   4         5
# a    b   c   d   e   program
# 1    2   3   4   5    pandas
# 6    7   8   9  10     numpy
# 11  12  13  14  15    python

# %% [markdown]
# * CSV 파일 저장

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.to_csv("outcome.csv")

# %% [markdown]
# * txt 파일 불러와 읽기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * txt 파일 저장하기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 엑셀 파일 불러와 읽기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 엑셀 파일 저장

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 코랩(colab)에서 로컬 컴퓨터로 파일 다운로드
